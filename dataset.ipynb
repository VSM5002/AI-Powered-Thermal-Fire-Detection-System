# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("vijayveersingh/nasa-firms-active-fire-dataset-modisviirs")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 132M/132M [03:42<00:00, 623kB/s]
# Extracting files...
# Path to dataset files: C:\Users\Admin\.cache\kagglehub\datasets\vijayveersingh\nasa-firms-active-fire-dataset-modisviirs\versions\1

# %%
import os

path = r"C:\Users\Admin\.cache\kagglehub\datasets\vijayveersingh\nasa-firms-active-fire-dataset-modisviirs\versions\1"
files = os.listdir(path)

print("Files in dataset folder:")
for f in files:
    print(f)
# Out:
# Files in dataset folder:
# fire_nrt_J1V-C2_565335.csv
# fire_nrt_M-C61_565334.csv
# fire_nrt_SV-C2_565336.csv
# Readme.txt

# %%
import pandas as pd

# Example: replace with actual filename from previous output
csv_file = os.path.join(path, "fire_nrt_J1V-C2_565335.csv")

df = pd.read_csv(csv_file)

# Preview data
print(df.head())
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0  70.39933   68.27425      323.29  0.32   0.55  2024-11-01        43
# 1  70.39788   68.27815      338.50  0.32   0.55  2024-11-01        43
# 2  70.38014   68.29300      320.24  0.32   0.55  2024-11-01        43
# 3  65.77070   24.18973      323.35  0.41   0.37  2024-11-01        48
# 4  65.76741   24.18719      338.44  0.41   0.37  2024-11-01        48
#
#   satellite instrument confidence version  bright_t31   frp daynight
# 0       N20      VIIRS          n  2.0NRT      258.44  3.14        N
# 1       N20      VIIRS          n  2.0NRT      260.52  3.08        N
# 2       N20      VIIRS          n  2.0NRT      254.21  1.92        N
# 3       N20      VIIRS          n  2.0NRT      266.97  1.64        N
# 4       N20      VIIRS          n  2.0NRT      269.87  5.80        N

# %%
pip install opencv-contrib-python
# Out:
# ...
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/46.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/46.2 MB ? eta -:--:--
#    ---------------------------------------- 0.5/46.2 MB 730.2 kB/s eta 0:01:03
#    ---------------------------------------- 0.5/46.2 MB 730.2 kB/s eta 0:01:03
#     --------------------------------------- 0.8/46.2 MB 685.3 kB/s eta 0:01:07
#     --------------------------------------- 0.8/46.2 MB 685.3 kB/s eta 0:01:07
#     --------------------------------------- 1.0/46.2 MB 613.9 kB/s eta 0:01:14
#     --------------------------------------- 1.0/46.2 MB 613.9 kB/s eta 0:01:14
#    - -------------------------------------- 1.3/46.2 MB 615.7 kB/s eta 0:01:13
#    - -------------------------------------- 1.3/46.2 MB 615.7 kB/s eta 0:01:13
# ...
